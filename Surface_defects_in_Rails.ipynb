# %% [raw]
# Surface Defects on Rails of Bhilai Steel Plant :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd

file_path = r'C:\Users\diksh\OneDrive\Desktop\projects\New folder\RSM YEARWISE DATA.xlsx' 
df = pd.read_excel(file_path, sheet_name="Sheet1")
df
# Out:
#     Unnamed: 0                         Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0          NaN                                NaN         NaN        NaN
# 1          NaN  RSM COMBINED RAIL INSPECTION DATA         NaN        NaN
# 2          NaN                                        2019-20        NaN
# 3          NaN                                NaN        TONS          %
# 4          NaN                  GR.880/R260 PRIME   746816.32  84.813894
# 5          NaN                GR. 880 IU/ R260 IU    17878.49   2.030411
# 6          NaN                    COMMERCIAL RAIL    85022.12    9.65573
# 7          NaN                          REJECTION    16339.13    1.85559
# 8          NaN                       UT REJECTION   14479.297   1.644374
# 9          NaN                        CLASSIFIED   880535.357      100.0
# 10         NaN                      REJ./DWN GRD.  133719.037  15.186106
#
#        Unnamed: 4 Unnamed: 5     Unnamed: 6 Unnamed: 7     Unnamed: 8  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11'])
df
# Out:
#                            Unnamed: 1  Unnamed: 2     Unnamed: 4  \
# 0                                 NaN         NaN            NaN
# 1   RSM COMBINED RAIL INSPECTION DATA         NaN            NaN
# 2                                         2019-20        2020-21
# 3                                 NaN        TONS           TONS
# 4                   GR.880/R260 PRIME   746816.32     492263.533
# 5                 GR. 880 IU/ R260 IU    17878.49        2008.05
# 6                     COMMERCIAL RAIL    85022.12      65461.377
# 7                           REJECTION    16339.13       9039.361
# 8                        UT REJECTION   14479.297    8773.730282
# 9                         CLASSIFIED   880535.357  577546.051282
# 10                      REJ./DWN GRD.  133719.037   85282.518282
#
#        Unnamed: 6     Unnamed: 8 Unnamed: 10
# 0             NaN            NaN         NaN
# 1             NaN            NaN         NaN
# 2         2021-22       2022-23     2023-24
# ...

# %%
df = df.drop([0, 1,3])
df
# Out:
#              Unnamed: 1  Unnamed: 2     Unnamed: 4     Unnamed: 6  \
# 2                           2019-20        2020-21        2021-22
# 4     GR.880/R260 PRIME   746816.32     492263.533    380217.0875
# 5   GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095
# 6       COMMERCIAL RAIL    85022.12      65461.377      73357.496
# 7             REJECTION    16339.13       9039.361       7487.886
# 8          UT REJECTION   14479.297    8773.730282    9376.261745
# 9           CLASSIFIED   880535.357  577546.051282  484781.826245
# 10        REJ./DWN GRD.  133719.037   85282.518282  104564.738745
#
#        Unnamed: 8 Unnamed: 10
# 2        2022-23     2023-24
# 4      395735.155  353355.135
# 5       25810.067   20562.714
# 6       52488.086   40970.257
# 7     4858.520542    3837.334
# 8      9593.10458     6180.82
# 9   488484.933122   424906.26
# 10   92749.778122   71551.125

# %%
df = df.drop([2])
df
# Out:
#              Unnamed: 1  Unnamed: 2     Unnamed: 4     Unnamed: 6  \
# 4     GR.880/R260 PRIME   746816.32     492263.533    380217.0875
# 5   GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095
# 6       COMMERCIAL RAIL    85022.12      65461.377      73357.496
# 7             REJECTION    16339.13       9039.361       7487.886
# 8          UT REJECTION   14479.297    8773.730282    9376.261745
# 9           CLASSIFIED   880535.357  577546.051282  484781.826245
# 10        REJ./DWN GRD.  133719.037   85282.518282  104564.738745
#
#        Unnamed: 8 Unnamed: 10
# 4      395735.155  353355.135
# 5       25810.067   20562.714
# 6       52488.086   40970.257
# 7     4858.520542    3837.334
# 8      9593.10458     6180.82
# 9   488484.933122   424906.26
# 10   92749.778122   71551.125

# %%
df.columns = ['Catergory', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
df
# Out:
#               Catergory     2019-20        2020-21        2021-22  \
# 4     GR.880/R260 PRIME   746816.32     492263.533    380217.0875
# 5   GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095
# 6       COMMERCIAL RAIL    85022.12      65461.377      73357.496
# 7             REJECTION    16339.13       9039.361       7487.886
# 8          UT REJECTION   14479.297    8773.730282    9376.261745
# 9           CLASSIFIED   880535.357  577546.051282  484781.826245
# 10        REJ./DWN GRD.  133719.037   85282.518282  104564.738745
#
#           2022-23     2023-24
# 4      395735.155  353355.135
# 5       25810.067   20562.714
# 6       52488.086   40970.257
# 7     4858.520542    3837.334
# 8      9593.10458     6180.82
# 9   488484.933122   424906.26
# 10   92749.778122   71551.125

# %%
df
# Out:
#               Catergory     2019-20        2020-21        2021-22  \
# 4     GR.880/R260 PRIME   746816.32     492263.533    380217.0875
# 5   GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095
# 6       COMMERCIAL RAIL    85022.12      65461.377      73357.496
# 7             REJECTION    16339.13       9039.361       7487.886
# 8          UT REJECTION   14479.297    8773.730282    9376.261745
# 9           CLASSIFIED   880535.357  577546.051282  484781.826245
# 10        REJ./DWN GRD.  133719.037   85282.518282  104564.738745
#
#           2022-23     2023-24
# 4      395735.155  353355.135
# 5       25810.067   20562.714
# 6       52488.086   40970.257
# 7     4858.520542    3837.334
# 8      9593.10458     6180.82
# 9   488484.933122   424906.26
# 10   92749.778122   71551.125

# %%
df
# Out:
#               Catergory     2019-20        2020-21        2021-22  \
# 4     GR.880/R260 PRIME   746816.32     492263.533    380217.0875
# 5   GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095
# 6       COMMERCIAL RAIL    85022.12      65461.377      73357.496
# 7             REJECTION    16339.13       9039.361       7487.886
# 8          UT REJECTION   14479.297    8773.730282    9376.261745
# 9           CLASSIFIED   880535.357  577546.051282  484781.826245
# 10        REJ./DWN GRD.  133719.037   85282.518282  104564.738745
#
#           2022-23     2023-24
# 4      395735.155  353355.135
# 5       25810.067   20562.714
# 6       52488.086   40970.257
# 7     4858.520542    3837.334
# 8      9593.10458     6180.82
# 9   488484.933122   424906.26
# 10   92749.778122   71551.125

# %%
df.transpose()
# Out:
#                           4                    5                6   \
# Catergory  GR.880/R260 PRIME  GR. 880 IU/ R260 IU  COMMERCIAL RAIL
# 2019-20            746816.32             17878.49         85022.12
# 2020-21           492263.533              2008.05        65461.377
# 2021-22          380217.0875            14343.095        73357.496
# 2022-23           395735.155            25810.067        52488.086
# 2023-24           353355.135            20562.714        40970.257
#
#                     7             8              9              10
# Catergory    REJECTION  UT REJECTION    CLASSIFIED   REJ./DWN GRD.
# 2019-20       16339.13     14479.297     880535.357     133719.037
# 2020-21       9039.361   8773.730282  577546.051282   85282.518282
# 2021-22       7487.886   9376.261745  484781.826245  104564.738745
# 2022-23    4858.520542    9593.10458  488484.933122   92749.778122
# 2023-24       3837.334       6180.82      424906.26      71551.125

# %%
df.set_index('Catergory', inplace=True)

# %%
df
# Out:
#                         2019-20        2020-21        2021-22        2022-23  \
# Catergory
# GR.880/R260 PRIME     746816.32     492263.533    380217.0875     395735.155
# GR. 880 IU/ R260 IU    17878.49        2008.05      14343.095      25810.067
# COMMERCIAL RAIL        85022.12      65461.377      73357.496      52488.086
# REJECTION              16339.13       9039.361       7487.886    4858.520542
# UT REJECTION          14479.297    8773.730282    9376.261745     9593.10458
# CLASSIFIED           880535.357  577546.051282  484781.826245  488484.933122
# REJ./DWN GRD.        133719.037   85282.518282  104564.738745   92749.778122
#
#                         2023-24
# Catergory
# GR.880/R260 PRIME    353355.135
# GR. 880 IU/ R260 IU   20562.714
# COMMERCIAL RAIL       40970.257
# REJECTION              3837.334
# UT REJECTION            6180.82
# CLASSIFIED            424906.26
# REJ./DWN GRD.         71551.125

# %%
df = df.T
plt.figure(figsize=(14, 8))
for column in df.columns:
    plt.plot(df.index, df[column], marker='o', label=column)
    
plt.title('Category Data Over Years')
plt.xlabel('Year')
plt.ylabel('Values (in tons)')
plt.legend(loc='upper right')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
file_path = r'C:\Users\diksh\OneDrive\Desktop\projects\New folder\RSM YEARWISE DATA.xlsx'  
df = pd.read_excel(file_path, sheet_name="Sheet2")
df
# Out:
#   FINISHING DEFECT  58317.109221  6.622915  Unnamed: 3  6.953158  Unnamed: 5  \
# 0           CAMBER   9082.865903  1.031516         NaN  0.861013         NaN
# 1               NS  21225.384178  2.410509         NaN  2.820821         NaN
# 2            KINKY  11810.915688  1.341333         NaN  1.725163         NaN
# 3            TWIST   6488.296745  0.736858         NaN  0.320453         NaN
# 4              MDF   9447.802954  1.072961         NaN  1.051771         NaN
# 5               SL    261.843753  0.029737         NaN  0.173937         NaN
#
#    10.116235  Unnamed: 7  8.634346  32056.463734  7.544361
# 0   1.498569         NaN  1.256712   2684.410956  0.631765
# 1   3.646777         NaN  2.418949  10422.043177  2.452786
# 2   2.050065         NaN  1.841345   6009.052112  1.414207
# 3   1.061952         NaN  0.512500   2377.244706  0.559475
# 4   1.774114         NaN  2.547619   9940.497782  2.339457
# 5   0.084758         NaN  0.057221    623.215000  0.146671

# %%
df.drop(columns=['Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7',58317.109221,32056.4637338], inplace = True)

# %%
df
# Out:
#   FINISHING DEFECT  6.622915  6.953158  10.116235  8.634346  7.544361
# 0           CAMBER  1.031516  0.861013   1.498569  1.256712  0.631765
# 1               NS  2.410509  2.820821   3.646777  2.418949  2.452786
# 2            KINKY  1.341333  1.725163   2.050065  1.841345  1.414207
# 3            TWIST  0.736858  0.320453   1.061952  0.512500  0.559475
# 4              MDF  1.072961  1.051771   1.774114  2.547619  2.339457
# 5               SL  0.029737  0.173937   0.084758  0.057221  0.146671

# %%
df.columns
# Out:
# Index(['FINISHING DEFECT',  6.622915111516639,   6.95315844386097,
#        10.116235129747876,  8.634345611401995, 7.5443613689758315],
#       dtype='object')

# %%
df.columns = ['FINISHING DEFECT', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']

# %%
df
# Out:
#   FINISHING DEFECT   2019-20   2020-21   2021-22   2022-23   2023-24
# 0           CAMBER  1.031516  0.861013  1.498569  1.256712  0.631765
# 1               NS  2.410509  2.820821  3.646777  2.418949  2.452786
# 2            KINKY  1.341333  1.725163  2.050065  1.841345  1.414207
# 3            TWIST  0.736858  0.320453  1.061952  0.512500  0.559475
# 4              MDF  1.072961  1.051771  1.774114  2.547619  2.339457
# 5               SL  0.029737  0.173937  0.084758  0.057221  0.146671

# %%
df.set_index('FINISHING DEFECT', inplace=True)
df
# Out:
#                    2019-20   2020-21   2021-22   2022-23   2023-24
# FINISHING DEFECT
# CAMBER            1.031516  0.861013  1.498569  1.256712  0.631765
# NS                2.410509  2.820821  3.646777  2.418949  2.452786
# KINKY             1.341333  1.725163  2.050065  1.841345  1.414207
# TWIST             0.736858  0.320453  1.061952  0.512500  0.559475
# MDF               1.072961  1.051771  1.774114  2.547619  2.339457
# SL                0.029737  0.173937  0.084758  0.057221  0.146671

# %%
for column in df.columns:
    plt.figure(figsize=(8, 6))
    df[column].plot.pie(autopct='%1.1f%%', startangle=140)
    plt.title(f'Finishing Defects Distribution in {column}')
    plt.ylabel('')  
    plt.show()

# %%
file_path = r'C:\Users\diksh\OneDrive\Desktop\projects\New folder\RSM YEARWISE DATA.xlsx'  
df = pd.read_excel(file_path, sheet_name="Sheet3")
df
# Out:
#   STEEL DEFECTS  1124.017021  0.127652  Unnamed: 3  0.064613  Unnamed: 5  \
# 0           NMI          NaN      0.13         NaN  0.000000         NaN
# 1          BLAP          NaN      0.00         NaN  0.064613         NaN
#
#    0.232814  Unnamed: 7  0.188733  329.120497  0.077457
# 0  0.019530         NaN  0.001441   13.363071  0.003145
# 1  0.213285         NaN  0.187292  315.757426  0.074312

# %%
df.set_index('STEEL DEFECTS', inplace=True)
df
# Out:
#                0.127652  0.064613  0.232814  0.188733  0.077457
# STEEL DEFECTS
# NMI                0.13  0.000000  0.019530  0.001441  0.003145
# BLAP               0.00  0.064613  0.213285  0.187292  0.074312

# %%
df.columns
# Out:
# Index([0.12765154880657448, 0.06461294318810804, 0.23281445276366536,
#         0.1887328418562737, 0.07745720135071676],
#       dtype='object')

# %%
df.columns
# Out:
# Index([    'STEEL DEFECTS',         1124.017021, 0.12765154880657448,
#               'Unnamed: 3', 0.06461294318810804,        'Unnamed: 5',
#        0.23281445276366536,        'Unnamed: 7',  0.1887328418562737,
#               329.12049736, 0.07745720135071676],
#       dtype='object')

# %%
df.columns = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24']

# %%
df
# Out:
#                2019-20   2020-21   2021-22   2022-23   2023-24
# STEEL DEFECTS
# NMI               0.13  0.000000  0.019530  0.001441  0.003145
# BLAP              0.00  0.064613  0.213285  0.187292  0.074312

# %%
df_transposed = df.T

df_transposed.plot(kind='bar', figsize=(12, 8))

plt.title('Steel Defects by Year')
plt.xlabel('Year')
plt.ylabel('Value')
plt.xticks(rotation=45) 

plt.tight_layout()
plt.show()

# %%
file_path = r'C:\Users\diksh\OneDrive\Desktop\projects\New folder\RSM YEARWISE DATA.xlsx' 
df = pd.read_excel(file_path, sheet_name="Sheet4")
df
# Out:
#   MILL DEFECTS  59795.874663  6.790854  Unnamed: 3  6.227397  Unnamed: 5  \
# 0           SV  20664.799941  2.346845         NaN  1.673532         NaN
# 1         ASSY   6440.193603  0.731395         NaN  0.622309         NaN
# 2           BR   5566.496651  0.632172         NaN  0.475896         NaN
# 3          NHN    601.289419  0.068287         NaN  0.028487         NaN
# 4          MDM   6007.427594  0.682247         NaN  0.692207         NaN
# 5           GM   1350.438647  0.153366         NaN  0.193618         NaN
# 6          LAP  19165.228808  2.176543         NaN  2.541348         NaN
#
#    9.286108  Unnamed: 7  8.200396  32984.171849  7.762694
# 0  2.769709         NaN  1.466651   3811.074273  0.896921
# 1  0.878929         NaN  0.493419   1412.639115  0.332459
# 2  0.901659         NaN  1.738513   9247.284453  2.176312
# 3  0.030377         NaN  0.033238    275.002826  0.064721
# 4  1.022831         NaN  1.357935   4531.775896  1.066535
# ...

# %%
df.set_index('MILL DEFECTS', inplace=True)
df
# Out:
#               59795.874663  6.790854  Unnamed: 3  6.227397  Unnamed: 5  \
# MILL DEFECTS
# SV            20664.799941  2.346845         NaN  1.673532         NaN
# ASSY           6440.193603  0.731395         NaN  0.622309         NaN
# BR             5566.496651  0.632172         NaN  0.475896         NaN
# NHN             601.289419  0.068287         NaN  0.028487         NaN
# MDM            6007.427594  0.682247         NaN  0.692207         NaN
# GM             1350.438647  0.153366         NaN  0.193618         NaN
# LAP           19165.228808  2.176543         NaN  2.541348         NaN
#
#               9.286108  Unnamed: 7  8.200396  32984.171849  7.762694
# MILL DEFECTS
# SV            2.769709         NaN  1.466651   3811.074273  0.896921
# ASSY          0.878929         NaN  0.493419   1412.639115  0.332459
# BR            0.901659         NaN  1.738513   9247.284453  2.176312
# NHN           0.030377         NaN  0.033238    275.002826  0.064721
# ...

# %%
df.drop(columns=[59795.8746632, 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7',32984.17184946], inplace = True)

# %%
df
# Out:
#               6.790854  6.227397  9.286108  8.200396  7.762694
# MILL DEFECTS
# SV            2.346845  1.673532  2.769709  1.466651  0.896921
# ASSY          0.731395  0.622309  0.878929  0.493419  0.332459
# BR            0.632172  0.475896  0.901659  1.738513  2.176312
# NHN           0.068287  0.028487  0.030377  0.033238  0.064721
# MDM           0.682247  0.692207  1.022831  1.357935  1.066535
# GM            0.153366  0.193618  0.567338  0.198957  0.228056
# LAP           2.176543  2.541348  3.115266  2.911683  2.997689

# %%
df.columns = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
df
# Out:
#                2019-20   2020-21   2021-22   2022-23   2023-24
# MILL DEFECTS
# SV            2.346845  1.673532  2.769709  1.466651  0.896921
# ASSY          0.731395  0.622309  0.878929  0.493419  0.332459
# BR            0.632172  0.475896  0.901659  1.738513  2.176312
# NHN           0.068287  0.028487  0.030377  0.033238  0.064721
# MDM           0.682247  0.692207  1.022831  1.357935  1.066535
# GM            0.153366  0.193618  0.567338  0.198957  0.228056
# LAP           2.176543  2.541348  3.115266  2.911683  2.997689

# %%
df_transposed = df.T

df_transposed.plot(kind='line', figsize=(12, 8), marker='o')

plt.title('Mill Defects Over Years')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend(title='Mill Defects')
plt.xticks(rotation=0) 

plt.tight_layout()
plt.show()
